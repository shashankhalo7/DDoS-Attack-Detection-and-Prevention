# %% [markdown]
# ## Attack Detection

# %%
import pandas as pd
import numpy as np
import scipy 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from pandas_ml import ConfusionMatrix

from sklearn import svm
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier,ExtraTreesClassifier 
from sklearn import preprocessing
import itertools

# %%
df = pd.read_excel("SNMPdataset.xlsx")
df.drop(df.index[0],inplace=True)
df.head(5)
# Out:
#                                 SNMP Parameters icmp_AddrMaskReps  \
# 1  Mon Jul 31 15:49:58 UTC 2017 Counter32 value                 0
# 2  Mon Jul 31 15:50:31 UTC 2017 Counter32 value                 0
# 3  Mon Jul 31 15:51:10 UTC 2017 Counter32 value                 0
# 4  Mon Jul 31 15:51:44 UTC 2017 Counter32 value                 0
# 5  Mon Jul 31 15:52:24 UTC 2017 Counter32 value                 0
#
#   icmp_InAddrMasks icmp_InDestUnreachs icmp_InEchosReps icmp_InEchos  \
# 1                0                   0               16            0
# 2                0                   0              111            0
# 3                0                   0              229            0
# 4                0                   0                0            0
# 5                0                   0              442            0
#
#   icmp_InErrors icmp_InMsgs icmp_InParmProbs icmp_InRedirects    ...      \
# 1             0          17                0                0    ...
# 2             0         112                0                0    ...
# 3             0         230                0                0    ...
# 4             0         332                0                0    ...
# 5             0         443                0                0    ...
#
#   tcp_PassiveOpens tcp_RetransSegs tcp_RtoAlgorithm tcp_RtoMax tcp_RtoMin  \
# 1                1               0                1     120000        200
# 2                2               0                1     120000        200
# 3                2               0                1     120000        200
# 4                2               0                1     120000        200
# 5                2               0                1     120000        200
#
#   udp_InDatagrams udp_InErrors udp_NoPorts udp_OutDatagrams ClassLabel
# 1             148            0           1              149     Normal
# 2             445            0           1              446     Normal
# 3             741            0           1              742     Normal
# 4            1037            0           1             1038     Normal
# 5            1333            0           1             1334     Normal
#
# [5 rows x 66 columns]

# %%
df['ClassLabel'].unique()
# Out:
# array(['Normal', 'Attack'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2421 entries, 1 to 2421
# Data columns (total 66 columns):
# SNMP Parameters           2421 non-null object
# icmp_AddrMaskReps         2421 non-null object
# icmp_InAddrMasks          2421 non-null object
# icmp_InDestUnreachs       2421 non-null object
# icmp_InEchosReps          2421 non-null object
# icmp_InEchos              2421 non-null object
# icmp_InErrors             2421 non-null object
# icmp_InMsgs               2421 non-null object
# icmp_InParmProbs          2421 non-null object
# icmp_InRedirects          2421 non-null object
# icmp_InSrcQuenchs         2421 non-null object
# icmp_InTimeExcds          2421 non-null object
# icmp_InTimestampReps      2421 non-null object
# icmp_InTimestamps         2421 non-null object
# icmp_OutAddrMaskReps      2421 non-null object
# icmp_OutAddrMasks         2421 non-null object
# icmp_OutDestUnreachs      2421 non-null object
# icmp_OutEchoReps          2421 non-null object
# icmp_OutEchos             2421 non-null object
# icmp_OutErrors            2421 non-null object
# icmp_OutMsgs              2421 non-null object
# icmp_OutParmProbs         2421 non-null object
# icmp_OutRedirects         2421 non-null object
# icmp_OutSrcQuenchs        2421 non-null object
# icmp_OutTimeExcds         2421 non-null object
# icmp_OutTimestampsReps    2421 non-null object
# icmp_OutTimestamps        2421 non-null object
# ip_DefaultTTL             2421 non-null object
# ip_Forwarding             2421 non-null object
# ip_ForwDatagrams          2421 non-null object
# ip_FragCreates            2421 non-null object
# ip_FragFails              2421 non-null object
# ip_FragOKs                2421 non-null object
# ip_InAddrErrors           2421 non-null object
# ip_InDelivers             2421 non-null object
# ip_InDiscard              2421 non-null object
# ip_InHdrErrors            2421 non-null object
# ip_InReceives             2421 non-null object
# ip_InUnknownProtos        2421 non-null object
# ip_OutDiscards            2421 non-null object
# ip_OutNoRoutes            2421 non-null object
# ip_OutRequests            2421 non-null object
# ip_ReasmFails             2421 non-null object
# ip_ReasmOKs               2421 non-null object
# ip_ReasmReqds             2421 non-null object
# ip_ReasmTimeout           2421 non-null object
# ip_RoutingDiscards        2421 non-null object
# tcp_ActiveOpens           2421 non-null object
# tcp_AttemptFails          2421 non-null object
# tcp_CurrEstablish         2421 non-null object
# tcp_EstabResets           2421 non-null object
# tcp_InErrs                2421 non-null object
# tcp_InSegs                2421 non-null object
# tcp_MaxConn               2421 non-null object
# tcp_OutRsts               2421 non-null object
# tcp_OutSegs               2421 non-null object
# tcp_PassiveOpens          2421 non-null object
# tcp_RetransSegs           2421 non-null object
# tcp_RtoAlgorithm          2421 non-null object
# tcp_RtoMax                2421 non-null object
# tcp_RtoMin                2421 non-null object
# udp_InDatagrams           2421 non-null object
# udp_InErrors              2421 non-null object
# udp_NoPorts               2421 non-null object
# udp_OutDatagrams          2421 non-null object
# ClassLabel                2421 non-null object
# dtypes: object(66)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                      SNMP Parameters  icmp_AddrMaskReps  icmp_InAddrMasks  \
# count                           2421               2421              2421
# unique                          2421                  1                 1
# top     Thu Apr 13 11:32:23 UTC 2017                  0                 0
# freq                               1               2421              2421
#
#         icmp_InDestUnreachs  icmp_InEchosReps  icmp_InEchos  icmp_InErrors  \
# count                  2421              2421          2421           2421
# unique                    1               416             1             22
# top                       0                 0             0              0
# freq                   2421              1997          2421           2182
#
#         icmp_InMsgs  icmp_InParmProbs  icmp_InRedirects     ...      \
# count          2421              2421              2421     ...
# unique          449                 1                 1     ...
# top               1                 0                 0     ...
# freq           1760              2421              2421     ...
#
#         tcp_PassiveOpens  tcp_RetransSegs  tcp_RtoAlgorithm  tcp_RtoMax  \
# count               2421             2421              2421        2421
# unique                 6               58                 1           1
# top                    2                0                 1      120000
# freq                1929             1001              2421        2421
#
#         tcp_RtoMin  udp_InDatagrams  udp_InErrors  udp_NoPorts  \
# count         2421             2421          2421         2421
# unique           1             1391             1          505
# top            200            46917             0            1
# freq          2421                5          2421         1316
#
#         udp_OutDatagrams  ClassLabel
# count               2421        2421
# unique              1418           2
# top                15838      Normal
# freq                   6        1250
#
# [4 rows x 66 columns]

# %%
df1 = df.iloc[:,:28]
sns.pairplot(df.dropna(),vars=df1.columns,hue= 'ClassLabel')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-00ad5f29a9ba> in <module>()
#       1 df1 = df.iloc[:,:28]
# ----> 2 sns.pairplot(df.dropna(),vars=df1.columns,hue= 'ClassLabel')
#
# ~/.local/lib/python3.5/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, size, aspect, dropna, plot_kws, diag_kws, grid_kws)
#    2058     if grid.square_grid:
#    2059         if diag_kind == "hist":
# -> 2060             grid.map_diag(plt.hist, **diag_kws)
#    2061         elif diag_kind == "kde":
#    2062             diag_kws["legend"] = False
#
# ~/.local/lib/python3.5/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1363                     func(vals, color=color, **kwargs)
#    1364                 else:
# -> 1365                     func(vals, color=color, histtype="barstacked", **kwargs)
#    1366
#    1367             else:
#
# ~/.local/lib/python3.5/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3023                       histtype=histtype, align=align, orientation=orientation,
#    3024                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3025                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3026     finally:
#    3027         ax._hold = washold
#
# ~/.local/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6100
#    6101         # process the unit information
# -> 6102         self._process_unit_info(xdata=x, kwargs=kwargs)
#    6103         x = self.convert_xunits(x)
#    6104         if bin_range is not None:
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    1987             # we only need to update if there is nothing set yet.
#    1988             if not self.xaxis.have_units():
# -> 1989                 self.xaxis.update_units(xdata)
#    1990
#    1991         if ydata is not None:
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in update_units(self, data)
#    1436         neednew = self.converter != converter
#    1437         self.converter = converter
# -> 1438         default = self.converter.default_units(data, self)
#    1439         if default is not None and self.units is None:
#    1440             self.set_units(default)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/category.py in default_units(data, axis)
#      70         # default_units->axis_info->convert
#      71         if axis.unit_data is None:
# ---> 72             axis.unit_data = UnitData(data)
#      73         else:
#      74             axis.unit_data.update(data)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/category.py in __init__(self, data)
#     102         """
#     103         self.seq, self.locs = [], []
# --> 104         self._set_seq_locs(data, 0)
#     105
#     106     def update(self, new_data):
#
# ~/.local/lib/python3.5/site-packages/matplotlib/category.py in _set_seq_locs(self, data, value)
#     110
#     111     def _set_seq_locs(self, data, value):
# --> 112         strdata = shim_array(data)
#     113         new_s = [d for d in np.unique(strdata) if d not in self.seq]
#     114         for ns in new_s:
#
# ~/.local/lib/python3.5/site-packages/matplotlib/category.py in shim_array(data)
#      19 if LooseVersion(np.__version__) >= LooseVersion('1.8.0'):
#      20     def shim_array(data):
# ---> 21         return np.array(data, dtype=np.unicode)
#      22 else:
#      23     def shim_array(data):
#
# ValueError: setting an array element with a sequence
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# ~/.local/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2216                     **kwargs)
#    2217                 renderer = self.figure._cachedRenderer
# -> 2218                 bbox_inches = self.figure.get_tightbbox(renderer)
#    2219
#    2220                 bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# ~/.local/lib/python3.5/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer)
#    1981         for ax in self.axes:
#    1982             if ax.get_visible():
# -> 1983                 bb.append(ax.get_tightbbox(renderer))
#    1984
#    1985         if len(bb) == 0:
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator)
#    4007
#    4008         if self.title.get_visible():
# -> 4009             bb.append(self.title.get_window_extent(renderer))
#    4010         if self._left_title.get_visible():
#    4011             bb.append(self._left_title.get_window_extent(renderer))
#
# ~/.local/lib/python3.5/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     923             self.figure.dpi = dpi
#     924         if self.get_text() == '':
# --> 925             tx, ty = self._get_xy_display()
#     926             return Bbox.from_bounds(tx, ty, 0, 0)
#     927
#
# ~/.local/lib/python3.5/site-packages/matplotlib/text.py in _get_xy_display(self)
#     232     def _get_xy_display(self):
#     233         'get the (possibly unit converted) transformed x, y in display coords'
# --> 234         x, y = self.get_unitless_position()
#     235         return self.get_transform().transform_point((x, y))
#     236
#
# ~/.local/lib/python3.5/site-packages/matplotlib/text.py in get_unitless_position(self)
#     853         # This will get the position with all unit information stripped away.
#     854         # This is here for convienience since it is done in several locations.
# --> 855         x = float(self.convert_xunits(self._x))
#     856         y = float(self.convert_yunits(self._y))
#     857         return x, y
#
# ~/.local/lib/python3.5/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     189         if ax is None or ax.xaxis is None:
#     190             return x
# --> 191         return ax.xaxis.convert_units(x)
#     192
#     193     def convert_yunits(self, y):
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1489             return x
#    1490
# -> 1491         ret = self.converter.convert(x, self.units, self)
#    1492         return ret
#    1493
#
# ~/.local/lib/python3.5/site-packages/matplotlib/category.py in convert(value, unit, axis)
#      47                 if isinstance(val, six.string_types):
#      48                     axis.unit_data.update(val)
# ---> 49         vmap = dict(zip(axis.unit_data.seq, axis.unit_data.locs))
#      50
#      51         if isinstance(value, six.string_types):
#
# AttributeError: 'NoneType' object has no attribute 'seq'

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def remove_similar(df):
    for col in df.columns:
        m=pd.unique(df[col]).tolist()
        if (len(m)==1):
            del df[col]
        else:
            pass
    return df

# %%
df= df.replace(0,np.nan)
df=df.dropna(how='all',axis=1)
df=df.replace(np.nan,0)
if "SNMP Parameters" in df.columns:
    del df["SNMP Parameters"]
col=['icmp_InEchosReps', 'icmp_InErrors', 'icmp_InMsgs', 'icmp_InTimeExcds']
df1=df[col].astype('float')
df = remove_similar(df)
df.head()
# Out:
#    icmp_InEchosReps  icmp_InErrors  icmp_InMsgs  icmp_InTimeExcds  \
# 1              16.0            0.0           17               1.0
# 2             111.0            0.0          112               1.0
# 3             229.0            0.0          230               1.0
# 4               0.0            0.0          332               1.0
# 5             442.0            0.0          443               1.0
#
#    icmp_InTimestamps  icmp_OutEchoReps  icmp_OutErrors  icmp_OutTimeExcds  \
# 1                0.0               0.0            17.0                1.0
# 2                0.0               0.0           112.0                1.0
# 3                0.0               0.0           230.0                1.0
# 4                0.0               0.0           347.0                1.0
# 5                0.0               0.0           443.0                1.0
#
#    icmp_OutTimestamps  ip_FragCreates     ...      tcp_EstabResets  \
# 1                16.0             0.0     ...                  0.0
# 2               127.0             0.0     ...                  0.0
# 3               229.0             0.0     ...                  0.0
# 4               346.0             0.0     ...                  0.0
# 5               442.0             0.0     ...                  0.0
#
#    tcp_InSegs  tcp_OutRsts  tcp_OutSegs  tcp_PassiveOpens  tcp_RetransSegs  \
# 1         178          0.0          213                 1              0.0
# 2         198          0.0          243                 2              0.0
# 3         255          0.0          282                 2              0.0
# 4         261          0.0          287                 2              0.0
# 5         273          0.0          296                 2              0.0
#
#    udp_InDatagrams  udp_NoPorts  udp_OutDatagrams  ClassLabel
# 1              148            1               149      Normal
# 2              445            1               446      Normal
# 3              741            1               742      Normal
# 4             1037            1              1038      Normal
# 5             1333            1              1334      Normal
#
# [5 rows x 29 columns]

# %%
df1= df.iloc[:,:28]
cm = np.corrcoef(df1.values.T)
sns.set(font_scale=1.5)
sns.set(rc={'figure.figsize':(15,15)})
hm = sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 8},yticklabels=df1.columns,xticklabels=df1.columns)

# %%
from sklearn.cross_validation import train_test_split
y = df['ClassLabel']
X = df.iloc[:,:28]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)
y_train=np.array(y_train).reshape(-1,1)
# Out:
# /home/witcher/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def models(X_train,X_test,y_train,y_test):
    names = ["K Nearest Neighbors", "XGBoost","Decision Tree", "Random Forest","ExtraTreesClassifier","SVM"]
    classifiers = [KNeighborsClassifier(20),
                   xgb.XGBClassifier(learning_rate=0.01, max_depth=5, n_estimators=100),
                   DecisionTreeClassifier(max_depth=2),
                   RandomForestClassifier(max_depth=5, n_estimators=100,max_features=7),
                   ExtraTreesClassifier(max_depth=5,n_estimators=100,max_features=7),
                   svm.SVC(kernel='linear')]
    for name, clf in zip(names, classifiers):
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        y_pred=clf.predict(X_test)
        #confusion_matrix = ConfusionMatrix(y_test, y_pred)
        #print("Confusion matrix:\n%s" % confusion_matrix)
        # Compute confusion matrix
        cnf_matrix = confusion_matrix(y_test, y_pred)
        np.set_printoptions(precision=2)
        # Plot non-normalized confusion matrix
        plt.figure()
        plot_confusion_matrix(cnf_matrix, classes=df['ClassLabel'].unique(),
                              title='Confusion matrix, without normalization')
        # Plot normalized confusion matrix
        plt.figure()
        plot_confusion_matrix(cnf_matrix, classes=df['ClassLabel'].unique(), normalize=True,
                              title='Normalized confusion matrix')
        plt.show()
        """
        print(name+' Score:',score)
        prediction1 = clf.predict(X_test)
        np.set_printoptions(precision=2)
    return 1

# %%
models(X_train,X_test,y_train,y_test)
# Out:
# /home/witcher/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/witcher/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/witcher/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# K Nearest Neighbors Score: 0.7606602475928473
# XGBoost Score: 0.9889958734525447
# Decision Tree Score: 0.889958734525447
# /home/witcher/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/witcher/.local/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/witcher/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# /home/witcher/.local/lib/python3.5/site-packages/ipykernel_launcher.py:10: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # Remove the CWD from sys.path while we load stuff.
# Random Forest Score: 0.9917469050894085
# ExtraTreesClassifier Score: 0.8885832187070152
# /home/witcher/.local/lib/python3.5/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
writer = pd.ExcelWriter('output.xlsx')
df.to_excel(writer,'Sheet1')
writer.save()

# %%
# !ls
